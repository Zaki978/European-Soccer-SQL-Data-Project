# %%
pip install pandas sqlalchemy ipython-sql

# %%
pip install --upgrade prettytable

# %%
pip install --upgrade ipython-sql

# %%
import sqlite3
import pandas as pd

# %%
import prettytable
prettytable.__dict__['DEFAULT'] = prettytable.PLAIN_COLUMNS
# Out:
# C:\Users\Zaki Bouaoudia\AppData\Local\Temp\ipykernel_15512\1122509105.py:2: DeprecationWarning: the 'PLAIN_COLUMNS' constant is deprecated, use the 'TableStyle' enum instead
#   prettytable.__dict__['DEFAULT'] = prettytable.PLAIN_COLUMNS

# %%
# List of CSV file paths
csv_files = {
    "Appearances": r"C:\Users\Zaki Bouaoudia\OneDrive\09_Programming\SQL Project\Football Database\appearances.csv",
    "Games": r"C:\Users\Zaki Bouaoudia\OneDrive\09_Programming\SQL Project\Football Database\games.csv",
    "Leagues": r"C:\Users\Zaki Bouaoudia\OneDrive\09_Programming\SQL Project\Football Database\leagues.csv",
    "Players": r"C:\Users\Zaki Bouaoudia\OneDrive\09_Programming\SQL Project\Football Database\players.csv",
    "Shots": r"C:\Users\Zaki Bouaoudia\OneDrive\09_Programming\SQL Project\Football Database\shots.csv",
    "Teams": r"C:\Users\Zaki Bouaoudia\OneDrive\09_Programming\SQL Project\Football Database\teams.csv",
    "TeamStats": r"C:\Users\Zaki Bouaoudia\OneDrive\09_Programming\SQL Project\Football Database\teamstats.csv",
}

# %%
# Create SQLite database (file-based)
db_file = "football_database.db"
conn = sqlite3.connect(db_file)  # Use a persistent database file

# %%
# Load each CSV into a separate table
for table_name, file_path in csv_files.items():
    try:
        # Specify a fallback encoding
        df = pd.read_csv(file_path, encoding='latin1')
        df.to_sql(table_name, conn, index=False, if_exists='replace')
        print(f"Loaded {file_path} into table {table_name}")
    except UnicodeDecodeError as e:
        print(f"Error loading {file_path}: {e}")
# Out:
# Loaded C:\Users\Zaki Bouaoudia\OneDrive\09_Programming\SQL Project\Football Database\appearances.csv into table Appearances
# Loaded C:\Users\Zaki Bouaoudia\OneDrive\09_Programming\SQL Project\Football Database\games.csv into table Games
# Loaded C:\Users\Zaki Bouaoudia\OneDrive\09_Programming\SQL Project\Football Database\leagues.csv into table Leagues
# Loaded C:\Users\Zaki Bouaoudia\OneDrive\09_Programming\SQL Project\Football Database\players.csv into table Players
# Loaded C:\Users\Zaki Bouaoudia\OneDrive\09_Programming\SQL Project\Football Database\shots.csv into table Shots
# Loaded C:\Users\Zaki Bouaoudia\OneDrive\09_Programming\SQL Project\Football Database\teams.csv into table Teams
# Loaded C:\Users\Zaki Bouaoudia\OneDrive\09_Programming\SQL Project\Football Database\teamstats.csv into table TeamStats

# %%
# Verify tables are loaded
print("Tables in the database:")
tables = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", conn)
print(tables)
# Out:
# Tables in the database:
#           name
# 0  Appearances
# 1        Games
# 2      Leagues
# 3      Players
# 4        Shots
# 5        Teams
# 6    TeamStats

# %%
# %load_ext sql

# %%
# %sql sqlite:///football_database.db

# %%
# %%sql
# SELECT COUNT(*)
# FROM Leagues
# Out:
#  * sqlite:///football_database.db
# Done.
# [(5,)]

# %%
#Query below finds all the IDs in the premier league

# %%
# %%sql
# SELECT DISTINCT homeTeamID as id
# FROM games
# WHERE leagueID in (SELECT leagueID
#                   FROM leagues
#                   WHERE leagueID = 1)
# Out:
#  * sqlite:///football_database.db
# Done.
# [(89,),
#  (73,),
#  (72,),
#  (75,),
#  (79,),
#  (80,),
#  (86,),
#  (83,),
#  (85,),
#  (76,),
#  (71,),
#  (74,),
#  (77,),
#  (84,),
#  (82,),
#  (90,),
#  (81,),
#  (78,),
#  (88,),
#  (87,),
#  (91,),
#  (92,),
#  (93,),
#  (202,),
#  (220,),
#  (219,),
#  (228,),
#  (229,),
#  (227,),
#  (238,),
#  (245,)]

# %%
#Display every team name in the premier league

# %%
# %%sql
# WITH premierLeagueIDs AS (SELECT DISTINCT homeTeamID as id
# FROM games
# WHERE leagueID in (SELECT leagueID
#                   FROM leagues
#                   WHERE leagueID = 1))
#
# SELECT t.teamID, t.name
# FROM teams t
# WHERE t.teamID in (SELECT id
#                    FROM premierLeagueIDs);
# Out:
#  * sqlite:///football_database.db
# Done.
# [(71, 'Aston Villa'),
#  (72, 'Everton'),
#  (74, 'Southampton'),
#  (75, 'Leicester'),
#  (76, 'West Bromwich Albion'),
#  (77, 'Sunderland'),
#  (78, 'Crystal Palace'),
#  (80, 'Chelsea'),
#  (81, 'West Ham'),
#  (82, 'Tottenham'),
#  (83, 'Arsenal'),
#  (84, 'Swansea'),
#  (85, 'Stoke'),
#  (86, 'Newcastle United'),
#  (87, 'Liverpool'),
#  (88, 'Manchester City'),
#  (89, 'Manchester United'),
#  (91, 'Hull'),
#  (92, 'Burnley'),
#  (202, 'Queens Park Rangers'),
#  (73, 'Bournemouth'),
#  (79, 'Norwich'),
#  (90, 'Watford'),
#  (93, 'Middlesbrough'),
#  (219, 'Huddersfield'),
#  (220, 'Brighton'),
#  (227, 'Cardiff'),
#  (228, 'Fulham'),
#  (229, 'Wolverhampton Wanderers'),
#  (238, 'Sheffield United'),
#  (245, 'Leeds')]

# %%
#Calculate how many goals Arsenal scored at home by season

# %%
# %%sql
# SELECT
#     season,
#     SUM(homegoals) as Total_Home_Goals
#
# FROM games g
# WHERE g.homeTeamID = 83
# GROUP BY season
# ORDER BY season;
# Out:
#  * sqlite:///football_database.db
# Done.
# [(2014, 41),
#  (2015, 31),
#  (2016, 39),
#  (2017, 54),
#  (2018, 42),
#  (2019, 36),
#  (2020, 24)]

# %%
#Calculate how many goals Arsenal scored at home vs away in 2020 season

# %%
# %%sql
# SELECT
#     season,
#     SUM(CASE WHEN homeTeamID = 83 THEN homegoals ELSE 0 END) AS Total_Home_Goals,
#     SUM(CASE WHEN awayTeamID = 83 THEN awaygoals ELSE 0 END) AS Total_Away_goals
# FROM games
# WHERE (homeTeamID = 83
#     OR awayTeamID = 83)
# GROUP BY season
# ORDER BY season;
# Out:
#  * sqlite:///football_database.db
# Done.
# [(2014, 41, 30),
#  (2015, 31, 34),
#  (2016, 39, 38),
#  (2017, 54, 20),
#  (2018, 42, 31),
#  (2019, 36, 20),
#  (2020, 24, 31)]

# %%
#Calculate the most goals scored by a team in the Premier league 2020 - this query is wrong redo it

# %%
# %%sql
# SELECT
#     MAX(homeGoals) AS MaxHomeGoals,
#     home.name AS HomeTeam,
#     MAX(awayGoals) AS MaxAwayGoals,
#     away.name AS AwayTeam
# FROM games g
# LEFT JOIN teams home ON g.homeTeamID = home.teamID
# LEFT JOIN teams away ON g.homeTeamID = away.teamID
# WHERE g.leagueID =1 AND g.season = '2020'

# %%
# Display all of the winners and losers in matches played during the 2020 in the premier league

# %%
# %%sql
#
# SELECT  g.season,
#         g.date,
#         (SELECT t.name
#          FROM teams t
#          WHERE t.teamID = g.homeTeamID
#         ) AS Home_Team,
#         (SELECT t.name
#          FROM teams t
#          WHERE t.teamID = g.awayTeamID
#         ) AS Away_Team,
#  (2020, '2020-09-14 17:00:00', 'Sheffield United', 'Wolverhampton Wanderers', 'Away Team Wins'),
#  (2020, '2020-09-13 15:30:00', 'Tottenham', 'Everton', 'Away Team Wins'),
#  (2020, '2020-09-13 13:00:00', 'West Bromwich Albion', 'Leicester', 'Away Team Wins'),
#  (2020, '2020-09-12 19:00:00', 'West Ham', 'Newcastle United', 'Away Team Wins'),
#  (2020, '2020-09-12 16:30:00', 'Liverpool', 'Leeds', 'Home Team Wins'),
#  (2020, '2020-09-12 14:00:00', 'Crystal Palace', 'Southampton', 'Home Team Wins'),
#  (2020, '2020-09-12 11:30:00', 'Fulham', 'Arsenal', 'Away Team Wins')]

# %%
#Same query as above writen differently

# %%
/*Please treat this as a comment*/
# %%sql
SELECT g.season, 
    g.date, 
    home.name AS HomeTeamName,
    away.name AS AwayTeamName,
    CASE 
        WHEN g.homeGoals > g.awayGoals THEN 'Home Team Wins'
        WHEN g.homeGoals < g.awayGoals THEN 'Away Team Wins'
        ELSE 'TIE' 
    END AS Winning_Side
FROM games g
INNER JOIN teams home ON g.homeTeamID = home.teamID
INNER JOIN teams away ON g.awayTeamID = away.teamID
WHERE g.leagueID = 1
ORDER BY g.date DESC;

# %%
#Rank teams according to the number of games won over all seasons for premier league teams

#first query is the previous one with a CTE

#Second Query calculate the HOme_games one for each team

# %%
# %%sql
#
# WITH premMatches AS (SELECT  g.season,
#         g.date,
#         (SELECT t.name
#          FROM teams t
#          WHERE t.teamID = g.homeTeamID
#         ) AS Home_Team,
#         (SELECT t.name
#          FROM teams t
#          WHERE t.teamID = g.awayTeamID
#         ) AS Away_Team,
#         (CASE WHEN homeGoals > awayGoals THEN "Home Team Wins"
#         WHEN homeGoals < awayGoals THEN "Away Team Wins"
#         ELSE 'Tie' END) As Winning_Side
# FROM games g
# WHERE leagueID = 1
# ORDER BY date DESC)
#
# SELECT TEAM, SUM(Wins) AS "Total Wins"
# FROM (
#
# SELECT Home_Team AS Team, COUNT(*) As Wins
# FROM premMatches
# WHERE Winning_Side = "Home Team Wins"
# GROUP BY Home_Team
#
# UNION ALL
#
# SELECT Away_Team AS TEAM, COUNT(*) As Wins
# FROM premMatches
# WHERE Winning_Side = "Away Team Wins"
# GROUP BY Away_Team
# ) AS Combined_Wins
# GROUP BY TEAM
# ORDER BY "Total Wins" DESC
# LIMIT 6;
# Out:
#  * sqlite:///football_database.db
# Done.
# [('Manchester City', 183),
#  ('Liverpool', 159),
#  ('Chelsea', 149),
#  ('Tottenham', 144),
#  ('Manchester United', 140),
#  ('Arsenal', 137)]

# %%
#Find the reiging champions in the permier league

SELECT homeTeamID, 
LAG(,1) OVer()
FROM games
WHERE leagueID = 1

# %%
#automate queries across all tables
for table_name in csv_files.keys():
    query = f"SELECT COUNT(*) AS row_count FROM {table_name};"
    result = pd.read_sql_query(query, conn)
    print(f"Table {table_name} has {result['row_count'][0]} rows.")

# %%
conn = sqlite3.connect('multi_table_database.db')
# Your tables are already saved if using this connection
conn.close()
